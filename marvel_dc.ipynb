# %% [markdown]
# <a href="https://colab.research.google.com/github/Sandy13283/marvel_dc/blob/main/marvel_dc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as pd
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
marvel=pd.read_csv('/content/drive/MyDrive/Data_set/marvel_demo_stats_powers.csv')

# %%
marvel.head()
# Out:
#    Unnamed: 0  ID           Name Alignment_x  Gender EyeColor  \
# 0           0   0         A-Bomb        good    Male   yellow
# 1           1   3    Abomination         bad    Male    green
# 2           2   4        Abraxas         bad    Male     blue
# 3           3   5  Absorbing Man         bad    Male     blue
# 4           4   8       Agent 13        good  Female     blue
#
#                 Race HairColor      Publisher SkinColor  ...  Web Creation  \
# 0              Human   No Hair  Marvel Comics         -  ...         False
# 1  Human / Radiation   No Hair  Marvel Comics         -  ...         False
# 2      Cosmic Entity     Black  Marvel Comics         -  ...         False
# 3              Human   No Hair  Marvel Comics         -  ...         False
# 4                  -     Blond  Marvel Comics         -  ...           NaN
#
#    Reality Warping  Odin Force  Symbiote Costume  Speed Force  Phoenix Force  \
# ...

# %%
marvel.shape
# Out:
# (382, 186)

# %%
for col in marvel:
  print(col)
# Out:
# Unnamed: 0
# ID
# Name
# Alignment_x
# Gender
# EyeColor
# Race
# HairColor
# Publisher
# SkinColor
# Height
# Weight
# Intelligence_x
# Strength
# Speed
# Durability_x
# Power
# Combat
# Total
# Agility
# Accelerated Healing
# Lantern Power Ring
# Dimensional Awareness
# Cold Resistance
# Durability_y
# Stealth
# Energy Absorption
# Flight
# Danger Sense
# Underwater breathing
# Marksmanship
# Weapons Master
# Power Augmentation
# Animal Attributes
# Longevity
# Intelligence_y
# Super Strength
# Cryokinesis
# Telepathy
# Energy Armor
# Energy Blasts
# Duplication
# Size Changing
# Density Control
# Stamina
# Astral Travel
# Audio Control
# Dexterity
# Omnitrix
# Super Speed
# Possession
# Animal Oriented Powers
# Weapon-based Powers
# Electrokinesis
# Darkforce Manipulation
# Death Touch
# Teleportation
# Enhanced Senses
# Telekinesis
# Energy Beams
# Magic
# Hyperkinesis
# Jump
# Clairvoyance
# Dimensional Travel
# Power Sense
# Shapeshifting
# Peak Human Condition
# Immortality
# ...

# %%
marvel['Alignment_x'].value_counts()
# Out:
# good       254
# bad        114
# neutral     11
# -            3
# Name: Alignment_x, dtype: int64

# %%
good=marvel[marvel['Alignment_x']=='good']

# %%
good.sort_values(by=['Speed'],ascending=False)
# Out:
#      Unnamed: 0   ID            Name Alignment_x  Gender      EyeColor  \
# 183         183  349  Jack of Hearts        good    Male  blue / white
# 43           43   95      Black Bolt        good    Male          blue
# 321         321  633        Stardust        good    Male             -
# 252         252  497         Nova II        good  Female         white
# 270         270  538     Quicksilver        good    Male          blue
# ..          ...  ...             ...         ...     ...           ...
# 262         262  524         Polaris        good  Female         green
# 300         300  597            Silk        good  Female         brown
# 311         311  621     Spider-Gwen        good  Female          blue
# 320         320  632       Star-Lord        good    Male          blue
# 342         342  679          Triton        good    Male         green
#
#                Race HairColor      Publisher SkinColor  ...  Web Creation  \
# ...

# %%
good[['Name','Gender','Speed','Combat']].sort_values(by=['Speed'],ascending=False)
# Out:
#                Name  Gender  Speed  Combat
# 183  Jack of Hearts    Male  100.0    30.0
# 43       Black Bolt    Male  100.0    56.0
# 321        Stardust    Male  100.0    85.0
# 252         Nova II  Female  100.0    25.0
# 270     Quicksilver    Male  100.0    56.0
# ..              ...     ...    ...     ...
# 262         Polaris  Female    NaN     NaN
# 300            Silk  Female    NaN     NaN
# 311     Spider-Gwen  Female    NaN     NaN
# 320       Star-Lord    Male    NaN     NaN
# 342          Triton    Male    NaN     NaN
#
# [254 rows x 4 columns]

# %%
good[['Name','Gender','Speed','Power']].sort_values(by=['Power'],ascending=False)
# Out:
#             Name  Gender  Speed  Power
# 252      Nova II  Female  100.0  100.0
# 177       Iceman    Male   53.0  100.0
# 43    Black Bolt    Male  100.0  100.0
# 260      Phoenix  Female   67.0  100.0
# 35      Beyonder    Male   23.0  100.0
# ..           ...     ...    ...    ...
# 262      Polaris  Female    NaN    NaN
# 300         Silk  Female    NaN    NaN
# 311  Spider-Gwen  Female    NaN    NaN
# 320    Star-Lord    Male    NaN    NaN
# 342       Triton    Male    NaN    NaN
#
# [254 rows x 4 columns]

# %%
good_max_power=good[good['Power']==100]
good_max_power.shape
good_max_power[['Name','Alignment_x','Gender','Strength','Speed','Power','Combat','Total']]
# Out:
#                Name Alignment_x  Gender  Strength  Speed  Power  Combat  Total
# 34    Beta Ray Bill        good    Male      80.0   35.0  100.0    84.0  457.0
# 35         Beyonder        good    Male     100.0   23.0  100.0    56.0  467.0
# 43       Black Bolt        good    Male      67.0  100.0  100.0    56.0  482.0
# 73            Cable        good    Male      48.0   23.0  100.0    80.0  395.0
# 115  Doctor Strange        good    Male      10.0   12.0  100.0    60.0  366.0
# 177          Iceman        good    Male      32.0   53.0  100.0    64.0  412.0
# 181        Iron Man        good    Male      85.0   58.0  100.0    64.0  492.0
# 184       Jean Grey        good  Female      80.0   67.0  100.0    70.0  517.0
# 220     Marvel Girl        good  Female      85.0   47.0  100.0    80.0  417.0
# 251            Nova        good    Male      85.0   67.0  100.0    85.0  538.0
# 252         Nova II        good  Female      60.0  100.0  100.0    25.0  423.0
# ...

# %%
plt.figure(figsize=(10,8))
plt.bar(list(good_max_power['Name'])[0:8],list(good_max_power['Total'])[0:8],color=["purple","hotpink","blue",'red','yellow','green','olive','darkolivegreen','midnightblue'])
plt.show()

# %%
bad=marvel[marvel['Alignment_x']=='bad']
bad.head()
# Out:
#    Unnamed: 0  ID           Name Alignment_x Gender EyeColor  \
# 1           1   3    Abomination         bad   Male    green
# 2           2   4        Abraxas         bad   Male     blue
# 3           3   5  Absorbing Man         bad   Male     blue
# 7           7  11     Air-Walker         bad   Male     blue
# 8           8  12           Ajax         bad   Male    brown
#
#                 Race HairColor      Publisher SkinColor  ...  Web Creation  \
# 1  Human / Radiation   No Hair  Marvel Comics         -  ...         False
# 2      Cosmic Entity     Black  Marvel Comics         -  ...         False
# 3              Human   No Hair  Marvel Comics         -  ...         False
# 7                  -     White  Marvel Comics         -  ...         False
# 8             Cyborg     Black  Marvel Comics         -  ...         False
#
#    Reality Warping  Odin Force  Symbiote Costume  Speed Force  Phoenix Force  \
# ...

# %%
bad[['Name','Gender','Speed','Combat']].sort_values(by=['Speed'],ascending=False)
# Out:
#                Name Gender  Speed  Combat
# 7        Air-Walker   Male  100.0    40.0
# 129   Fallen One II   Male   83.0    56.0
# 120             Ego      -   83.0    28.0
# 118        Dormammu   Male   83.0    80.0
# 2           Abraxas   Male   83.0    56.0
# ..              ...    ...    ...     ...
# 268      Purple Man   Male    NaN     NaN
# 289  Sebastian Shaw   Male    NaN     NaN
# 305      Snake-Eyes   Male    NaN     NaN
# 324           Swarm   Male    NaN     NaN
# 326      Taskmaster   Male    NaN     NaN
#
# [114 rows x 4 columns]

# %%
bad[['Name','Gender','Speed','Combat','Intelligence_x']].sort_values(by=['Intelligence_x'],ascending=False)
# Out:
#                Name Gender  Speed  Combat  Intelligence_x
# 218        Mandarin   Male   23.0    95.0           100.0
# 17       Apocalypse   Male   33.0    60.0           100.0
# 194            Kang   Male   58.0    70.0           100.0
# 112     Doctor Doom   Male   20.0    84.0           100.0
# 339        Tinkerer   Male   23.0    14.0           100.0
# ..              ...    ...    ...     ...             ...
# 268      Purple Man   Male    NaN     NaN             NaN
# 289  Sebastian Shaw   Male    NaN     NaN             NaN
# 305      Snake-Eyes   Male    NaN     NaN             NaN
# 324           Swarm   Male    NaN     NaN             NaN
# 326      Taskmaster   Male    NaN     NaN             NaN
#
# [114 rows x 5 columns]

# %%
plt.figure(figsize=(10,6))
plt.hist(good['Speed'],bins=10,color="green")
plt.title('Distribution of speed')
plt.xlabel('Speed')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.hist(bad['Combat'],color='pink')
plt.title('Distribution of combat skills')
plt.xlabel("Combat")
plt.show()
